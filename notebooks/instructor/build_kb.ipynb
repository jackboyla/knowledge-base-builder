# %% [markdown]
# # 🌎 Build a KB against Wikipedia data

# %%
from typing import List, Optional, Any, Dict, Union
from pydantic import BaseModel, Field, field_validator
import instructor
from openai import OpenAI
import os
import json

from utils import save_jsonl, read_jsonl

# %%
client = instructor.patch(OpenAI(api_key=os.environ['OPENAI_API_KEY']))

# %%
class Property(BaseModel):
    property_name: str = Field(..., description="The property name.")
    property_value: Union[List[str], str, int, Dict[str, str]] = Field(..., description="The property value.") # 


    @field_validator('property_value')
    @classmethod
    def check_for_redundant_property(cls, property_value: str, info):
        # TODO: something smarter for this ?
        if type(property_value) == str:
            if property_value.lower() in ['yes', 'no', 'unknown']:
                raise ValueError(
                    f"The property value {property_value} is redundant. Please remove it."
                    )
        return property_value


class Entity(BaseModel):

    properties: Optional[List[Property]] = Field(
        ..., description="Extract any properties that are relevant in building a knowledge base for the entity."
    )

    def update(self, other: "Entity") -> "Entity":
        """Updates the current kb with the other kb."""
        # TODO: deduplicating
        self.properties += other.properties
        return self


class KnowledgeBase(BaseModel):
    entities: Dict[str, Entity] = {}


def generate_kb(entity, texts) -> Entity:

    cur_state = None
    num_iterations = len(texts)
    for i, inp in enumerate(texts):
        new_updates = client.chat.completions.create(
            model="gpt-3.5-turbo-0125",
            messages=[
                {
                    "role": "system",
                    "content": f"""You are an iterative knowledge base builder based on Wikidata.
                    You are given the current state of the knowledge base for entity {entity}, 
                    and you must add Wikidata-like property-value pairs
                    to it. Do not procide any duplcates.""",
                },
                {
                    "role": "user",
                    "content": f"""Extract any new information from the following:
                    # Part {i}/{num_iterations} of the input:

                    {inp}""",
                },
                # {
                #     "role": "user",
                #     "content": f"""Here is the current state of the graph:
                #     {cur_state.model_dump_json(indent=2) if cur_state is not None else 'empty'}""",
                # },  
            ],
            max_retries=2,
            response_model=Entity,
        )  # type: ignore

        if cur_state is None:
            cur_state = new_updates
        else:
            # Update the current state
            print(f"Merging new update: {new_updates.model_dump_json(indent=2)}")
            cur_state = cur_state.update(new_updates)

    return cur_state

# %%
wikidata_entities = read_jsonl('../../data/wikidata_entities.jsonl')
kb = KnowledgeBase()
entity1 = wikidata_entities[0]
kb.entities[entity1['entity_label']] = generate_kb(entity1['entity_label'], entity1['chunked_content'])
# Out:
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Occupation",
#       "property_value": "Politician and Activist"
#     },
#     {
#       "property_name": "Campaign Fundraising",
#       "property_value": "$3.09 million from individuals throughout Russia"
#     },
#     {
#       "property_name": "Campaign Volunteers",
#       "property_value": 20000
#     },
#     {
#       "property_name": "Campaign Coverage",
#       "property_value": "Received very little television coverage and did not utilize billboards"
#     },
#     {
#       "property_name": "Result of Election",
#       "property_value": "Received 27% of the vote in the mayoral election"
#     }
#   ]
# }
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Projects",
#       "property_value": [
#         "RosYama",
#         "Anti-Corruption Foundation",
#         "He Is Not Dimon to You"
#       ]
#     },
#     {
#       "property_name": "Scandalous Real Estate Deal",
#       "property_value": "Hungary sold a former embassy building in Moscow for US$21 million to an offshore company of Viktor Vekselberg, who immediately resold it to the Russian government for US$116 million"
#     }
#   ]
# }
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Incidents",
#       "property_value": [
#         "Investigative Committee of Russia asserted that Allekt defrauded the Union of Right Forces (SPS) political party in 2007",
#         "Navalny and his brother Oleg were charged with embezzling 55 million rubles in 2008–2011",
#         "Yandex search engine started artificially placing negative commentary about Navalny",
#         "Navalny alleged that Russian billionaire Yevgeny Prigozhin was linked to poor quality food supplied to schools",
#         "Navalny won six complaints against Russian authorities in the ECHR for a total of €225,000",
#         "Navalny was poisoned with a Novichok nerve agent",
#         "Joint investigation by The Insider and Bellingcat implicated agents from Russia's FSB in Navalny's poisoning",
#         "Navalny was followed by a unit linked to other deaths",
#         "Navalny returned to Russia and was detained at Sheremetyevo International Airport",
#         "Navalny was sentenced to over two and a half years in a corrective labour colony",
#         "Navalny accused authorities of torture and went on a hunger strike for proper medical treatment"
#       ]
#     }
#   ]
# }
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Date of hunger strike ending",
#       "property_value": "23 April 2021"
#     },
#     {
#       "property_name": "Statement on ending hunger strike",
#       "property_value": "Navalny announced that he was ending his hunger strike on advice of his doctors and as he felt his demands had been partially met"
#     },
#     {
#       "property_name": "Change in Navalny's political network",
#       "property_value": "Navalny's team announced that the political network would be dissolved, and the headquarters would be transformed into independent political organisations dealing with investigations, elections, public campaigns, and rallies"
#     },
#     {
#       "property_name": "Navalny's political network designated as extremist",
#       "property_value": "On 9 June 2021, Navalny's political network, including his headquarters and the FBK, were designated as extremist organisations and liquidated by the Moscow City Court"
#     }
#   ]
# }
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Political views",
#       "property_value": "Opponent of Putin's regime, advocate for government transparency and democracy"
#     },
#     {
#       "property_name": "Awards and Honours",
#       "property_value": [
#         "Person of the Year 2009 by Vedomosti and Stock in Focus",
#         "Finance magazine prize in 2010",
#         "World Fellow at Yale University's World Fellows Program in 2010",
#         "FP Top 100 Global Thinkers by Foreign Policy magazine in 2011 and 2012",
#         "One of Time magazine's 100 most influential people in 2012",
#         "Prize of the Platform of European Memory and Conscience 2015",
#         "Named in Time's list of the World's 25 Most Influential People on the Internet in 2017",
#         "Politician of the Year 2017 and 2019 by Vedomosti",
#         "Nominated for the 2021 Nobel Peace Prize",
#         "Boris Nemtsov Prize for Courage by the Boris Nemtsov Foundation for Freedom",
#         "Moral Courage Award at the Geneva Summit for Human Rights and Democracy in 2021",
#         "Included in Time's list of the 100 most influential people in September 2021",
#         "Awarded the Knight of Freedom Award in September 2021",
#         "Received the Sakharov Prize in October 2021",
#         "Received the M100 Media Award for sustaining freedom of expression in 2021",
#         "Received Best Documentary awards for the film 'Navalny' in 2023"
#       ]
#     }
#   ]
# }
# Merging new update: {
#   "properties": [
#     {
#       "property_name": "Marital Status",
#       "property_value": "Married"
#     },
#     {
#       "property_name": "Spouse",
#       "property_value": "Yulia Abrosimova"
#     },
#     {
#       "property_name": "Children",
#       "property_value": [
#         "Darya (Dasha) Navalnaya",
#         "Zakhar"
#       ]
#     },
#     {
#       "property_name": "Daughter's Education",
#       "property_value": "Undergraduate studies at Stanford University"
#     }
#   ]
# }

# %%
print(kb.model_dump_json(indent=2))
# Out:
# {
#   "entities": {
#     "Alexei Navalny": {
#       "properties": [
#         {
#           "property_name": "Full Name",
#           "property_value": "Alexei Anatolyevich Navalny"
#         },
#         {
#           "property_name": "Nationality",
#           "property_value": "Russian"
#         },
#         {
#           "property_name": "Date of Birth",
#           "property_value": "4 June 1976"
#         },
#         {
#           "property_name": "Date of Death",
#           "property_value": "16 February 2024"
#         },
#         {
#           "property_name": "Occupation",
#           "property_value": [
#             "Opposition Leader",
#             "Lawyer",
#             "Anti-corruption Activist",
#             "Political Prisoner"
#           ]
#         },
#         {
#           "property_name": "Occupation",
#           "property_value": "Politician and Activist"
#         },
#         {
#           "property_name": "Campaign Fundraising",
#           "property_value": "$3.09 million from individuals throughout Russia"
#         },
#         {
#           "property_name": "Campaign Volunteers",
#           "property_value": 20000
#         },
#         {
#           "property_name": "Campaign Coverage",
#           "property_value": "Received very little television coverage and did not utilize billboards"
#         },
#         {
#           "property_name": "Result of Election",
#           "property_value": "Received 27% of the vote in the mayoral election"
#         },
#         {
#           "property_name": "Projects",
#           "property_value": [
#             "RosYama",
#             "Anti-Corruption Foundation",
#             "He Is Not Dimon to You"
#           ]
#         },
#         {
#           "property_name": "Scandalous Real Estate Deal",
#           "property_value": "Hungary sold a former embassy building in Moscow for US$21 million to an offshore company of Viktor Vekselberg, who immediately resold it to the Russian government for US$116 million"
#         },
#         {
#           "property_name": "Incidents",
#           "property_value": [
#             "Investigative Committee of Russia asserted that Allekt defrauded the Union of Right Forces (SPS) political party in 2007",
#             "Navalny and his brother Oleg were charged with embezzling 55 million rubles in 2008–2011",
#             "Yandex search engine started artificially placing negative commentary about Navalny",
#             "Navalny alleged that Russian billionaire Yevgeny Prigozhin was linked to poor quality food supplied to schools",
#             "Navalny won six complaints against Russian authorities in the ECHR for a total of €225,000",
#             "Navalny was poisoned with a Novichok nerve agent",
#             "Joint investigation by The Insider and Bellingcat implicated agents from Russia's FSB in Navalny's poisoning",
#             "Navalny was followed by a unit linked to other deaths",
#             "Navalny returned to Russia and was detained at Sheremetyevo International Airport",
#             "Navalny was sentenced to over two and a half years in a corrective labour colony",
#             "Navalny accused authorities of torture and went on a hunger strike for proper medical treatment"
#           ]
#         },
#         {
#           "property_name": "Date of hunger strike ending",
#           "property_value": "23 April 2021"
#         },
#         {
#           "property_name": "Statement on ending hunger strike",
#           "property_value": "Navalny announced that he was ending his hunger strike on advice of his doctors and as he felt his demands had been partially met"
#         },
#         {
#           "property_name": "Change in Navalny's political network",
#           "property_value": "Navalny's team announced that the political network would be dissolved, and the headquarters would be transformed into independent political organisations dealing with investigations, elections, public campaigns, and rallies"
#         },
#         {
#           "property_name": "Navalny's political network designated as extremist",
#           "property_value": "On 9 June 2021, Navalny's political network, including his headquarters and the FBK, were designated as extremist organisations and liquidated by the Moscow City Court"
#         },
#         {
#           "property_name": "Political views",
#           "property_value": "Opponent of Putin's regime, advocate for government transparency and democracy"
#         },
#         {
#           "property_name": "Awards and Honours",
#           "property_value": [
#             "Person of the Year 2009 by Vedomosti and Stock in Focus",
#             "Finance magazine prize in 2010",
#             "World Fellow at Yale University's World Fellows Program in 2010",
#             "FP Top 100 Global Thinkers by Foreign Policy magazine in 2011 and 2012",
#             "One of Time magazine's 100 most influential people in 2012",
#             "Prize of the Platform of European Memory and Conscience 2015",
#             "Named in Time's list of the World's 25 Most Influential People on the Internet in 2017",
#             "Politician of the Year 2017 and 2019 by Vedomosti",
#             "Nominated for the 2021 Nobel Peace Prize",
#             "Boris Nemtsov Prize for Courage by the Boris Nemtsov Foundation for Freedom",
#             "Moral Courage Award at the Geneva Summit for Human Rights and Democracy in 2021",
#             "Included in Time's list of the 100 most influential people in September 2021",
#             "Awarded the Knight of Freedom Award in September 2021",
#             "Received the Sakharov Prize in October 2021",
#             "Received the M100 Media Award for sustaining freedom of expression in 2021",
#             "Received Best Documentary awards for the film 'Navalny' in 2023"
#           ]
#         },
#         {
#           "property_name": "Marital Status",
#           "property_value": "Married"
#         },
#         {
#           "property_name": "Spouse",
#           "property_value": "Yulia Abrosimova"
#         },
#         {
#           "property_name": "Children",
#           "property_value": [
#             "Darya (Dasha) Navalnaya",
#             "Zakhar"
#           ]
#         },
#         {
#           "property_name": "Daughter's Education",
#           "property_value": "Undergraduate studies at Stanford University"
#         }
#       ]
#     }
#   }
# }

# %%
out = []
out.append(kb.model_dump())
save_jsonl(out, '../../data/prediction.jsonl')
# Out:
# Saved to f'../../data/prediction.jsonl

# %%
kb.model_dump()
# Out:
# {'entities': {'Alexei Navalny': {'properties': [{'property_name': 'Full Name',
#      'property_value': 'Alexei Anatolyevich Navalny'},
#     {'property_name': 'Nationality', 'property_value': 'Russian'},
#     {'property_name': 'Date of Birth', 'property_value': '4 June 1976'},
#     {'property_name': 'Date of Death', 'property_value': '16 February 2024'},
#     {'property_name': 'Occupation',
#      'property_value': ['Opposition Leader',
#       'Lawyer',
#       'Anti-corruption Activist',
#       'Political Prisoner']},
#     {'property_name': 'Occupation',
#      'property_value': 'Politician and Activist'},
#     {'property_name': 'Campaign Fundraising',
#      'property_value': '$3.09 million from individuals throughout Russia'},
#     {'property_name': 'Campaign Volunteers', 'property_value': 20000},
#     {'property_name': 'Campaign Coverage',
#      'property_value': 'Received very little television coverage and did not utilize billboards'},
#     {'property_name': 'Result of Election',
#      'property_value': 'Received 27% of the vote in the mayoral election'},
#     {'property_name': 'Projects',
#      'property_value': ['RosYama',
#       'Anti-Corruption Foundation',
#       'He Is Not Dimon to You']},
#     {'property_name': 'Scandalous Real Estate Deal',
#      'property_value': 'Hungary sold a former embassy building in Moscow for US$21 million to an offshore company of Viktor Vekselberg, who immediately resold it to the Russian government for US$116 million'},
#     {'property_name': 'Incidents',
#      'property_value': ['Investigative Committee of Russia asserted that Allekt defrauded the Union of Right Forces (SPS) political party in 2007',
#       'Navalny and his brother Oleg were charged with embezzling 55 million rubles in 2008–2011',
#       'Yandex search engine started artificially placing negative commentary about Navalny',
#       'Navalny alleged that Russian billionaire Yevgeny Prigozhin was linked to poor quality food supplied to schools',
#       'Navalny won six complaints against Russian authorities in the ECHR for a total of €225,000',
#       'Navalny was poisoned with a Novichok nerve agent',
#       "Joint investigation by The Insider and Bellingcat implicated agents from Russia's FSB in Navalny's poisoning",
#       'Navalny was followed by a unit linked to other deaths',
#       'Navalny returned to Russia and was detained at Sheremetyevo International Airport',
#       'Navalny was sentenced to over two and a half years in a corrective labour colony',
#       'Navalny accused authorities of torture and went on a hunger strike for proper medical treatment']},
#     {'property_name': 'Date of hunger strike ending',
#      'property_value': '23 April 2021'},
#     {'property_name': 'Statement on ending hunger strike',
#      'property_value': 'Navalny announced that he was ending his hunger strike on advice of his doctors and as he felt his demands had been partially met'},
#     {'property_name': "Change in Navalny's political network",
#      'property_value': "Navalny's team announced that the political network would be dissolved, and the headquarters would be transformed into independent political organisations dealing with investigations, elections, public campaigns, and rallies"},
#     {'property_name': "Navalny's political network designated as extremist",
#      'property_value': "On 9 June 2021, Navalny's political network, including his headquarters and the FBK, were designated as extremist organisations and liquidated by the Moscow City Court"},
#     {'property_name': 'Political views',
#      'property_value': "Opponent of Putin's regime, advocate for government transparency and democracy"},
#     {'property_name': 'Awards and Honours',
#      'property_value': ['Person of the Year 2009 by Vedomosti and Stock in Focus',
#       'Finance magazine prize in 2010',
#       "World Fellow at Yale University's World Fellows Program in 2010",
#       'FP Top 100 Global Thinkers by Foreign Policy magazine in 2011 and 2012',
#       "One of Time magazine's 100 most influential people in 2012",
#       'Prize of the Platform of European Memory and Conscience 2015',
#       "Named in Time's list of the World's 25 Most Influential People on the Internet in 2017",
#       'Politician of the Year 2017 and 2019 by Vedomosti',
#       'Nominated for the 2021 Nobel Peace Prize',
#       'Boris Nemtsov Prize for Courage by the Boris Nemtsov Foundation for Freedom',
#       'Moral Courage Award at the Geneva Summit for Human Rights and Democracy in 2021',
#       "Included in Time's list of the 100 most influential people in September 2021",
#       'Awarded the Knight of Freedom Award in September 2021',
#       'Received the Sakharov Prize in October 2021',
#       'Received the M100 Media Award for sustaining freedom of expression in 2021',
#       "Received Best Documentary awards for the film 'Navalny' in 2023"]},
#     {'property_name': 'Marital Status', 'property_value': 'Married'},
#     {'property_name': 'Spouse', 'property_value': 'Yulia Abrosimova'},
#     {'property_name': 'Children',
#      'property_value': ['Darya (Dasha) Navalnaya', 'Zakhar']},
#     {'property_name': "Daughter's Education",
#      'property_value': 'Undergraduate studies at Stanford University'}]}}}

# %%
# inp = read_jsonl('../../data/prediction.jsonl')
# print(json.dumps(inp[0], indent=2))
