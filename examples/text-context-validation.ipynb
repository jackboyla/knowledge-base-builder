# %%
import sys
import os
sys.path.insert(0, '../knowledge_graph_validator')
os.environ['VALIDATION_MODEL'] = 'gpt-3.5-turbo-0125'
import validators

evaluator = validators.TextContextKGValidator

my_docs = [
    """Fictional News Story: The Mysterious Disappearance of the Celestial Diamond
In a stunning turn of events that has gripped the nation, the famed Celestial Diamond has vanished from the Metropolitan Museum, 
under circumstances as mysterious as the gem itself. The disappearance, discovered early Monday morning by museum security, 
has prompted an intense investigation led by Detective Jeanne Watson, a seasoned expert in art theft.
The Celestial Diamond, known for its unparalleled brilliance and storied history, was set to be the centerpiece of the museum's 
new exhibit on ancient treasures. Museum curator Alexander Hamilton had proudly announced the exhibit last month, emphasizing the 
diamond's significance in various historical epochs.
According to Detective Watson, the security footage mysteriously malfunctioned on the night of the theft, leaving no evidence of the thief's identity. 
However, a curious clue was left behind: a vintage pocket watch, engraved with the initials "N.B." This discovery has pointed investigators towards Nathan Bonaparte, 
a notorious but elusive art thief whose escapades have baffled authorities worldwide.
In an unexpected twist, renowned detective Sherlock Holmes, now a consultant on high-profile cases, has been called in to assist with the investigation. 
Holmes, known for his analytical prowess and deductive skills, believes that the theft might be an inside job. 
"The absence of forced entry and the malfunctioning of security cameras suggest a familiarity with the museum's security protocols," Holmes stated, 
casting a shadow of suspicion over the museum staff.
As the investigation unfolds, a mysterious figure known only as "The Phantom" has sent a cryptic message to the city's leading newspaper, 
claiming responsibility for the theft and challenging the detectives to a game of wits. The message promises a series of clues that will lead to the recovery of the diamond, 
setting the stage for a dramatic confrontation between the forces of law and the criminal mastermind.
With the city abuzz with rumors and speculation, the race is on to unravel the mystery of the Celestial Diamond's disappearance. 
Will Detective Watson and Sherlock Holmes outsmart The Phantom and recover the priceless gem, or will this prove to be the thief's greatest heist yet?"""
]

# %%
correct_triples = [
  {"subject": "Celestial Diamond", "relation": "vanished from", "object": "Metropolitan Museum"},
  {"subject": "Detective Jeanne Watson", "relation": "leads investigation of", "object": "Celestial Diamond disappearance"},
  {"subject": "Nathan Bonaparte", "relation": "suspected in", "object": "Celestial Diamond theft"},
  {"subject": "Sherlock Holmes", "relation": "called to assist", "object": "Celestial Diamond investigation"},
  {"subject": "The Phantom", "relation": "claims responsibility for", "object": "Celestial Diamond theft"}
]

incorrect_triples = [
  {"subject": "Alexander Hamilton", "relation": "stole", "object": "Celestial Diamond"},
  {"subject": "Celestial Diamond", "relation": "found in", "object": "Nathan Bonaparte's possession"},
  {"subject": "Detective Jeanne Watson", "relation": "distrusts", "object": "Sherlock Holmes"},
  {"subject": "The Phantom", "relation": "arrested by", "object": "Detective Watson"},
  {"subject": "Metropolitan Museum", "relation": "had functional security cameras", "object": "night of theft"}
]

inp = {'triples': correct_triples + incorrect_triples, 'documents': my_docs}

val = evaluator(**inp)
# Out:
# 100%|██████████| 10/10 [00:28<00:00,  2.85s/it]

# %%
import json
for v in val.model_dump()['validated_triples']:
    print(json.dumps(v, indent=2))
# Out:
# {
#   "predicted_subject_name": "Celestial Diamond",
#   "predicted_relation": "vanished from",
#   "predicted_object_name": "Metropolitan Museum",
#   "triple_is_valid": true,
#   "reason": "The predicted triple is accurate based on the provided context. The Celestial Diamond indeed vanished from the Metropolitan Museum as described in the fictional news story. The disappearance of the diamond is a central plot point in the narrative, triggering an investigation and creating a mystery around the event. The terms 'Celestial Diamond' and 'Metropolitan Museum' are relevant and clearly defined within the context, aligning with the story's details. The relation 'vanished from' accurately describes the action of the diamond disappearing from the museum. Overall, the triple captures the essence of the fictional event and is consistent with the information provided.",
#   "sources": {
#     "relevant_text": [
# ...

# %% [markdown]
# # 🗞️ Real-life News Article
#
# The events in this [BBC news article](https://www.bbc.co.uk/sport/formula1/68511360) happened after the cut-off date of GPT 3.5, so the model relies entirely on the provided context for facts.

# %%
# from https://www.bbc.co.uk/sport/formula1/68511360

article = '''Ferrari driver Carlos Sainz has been diagnosed with appendicitis and will miss the Saudi Arabian Grand Prix.

The Spaniard, 29, will be replaced for the rest of the weekend in Jeddah by the team's 18-year-old reserve driver Oliver Bearman, who will become the youngest Briton to race in Formula 1.

Sainz had been unwell for two days, saying Thursday practice was "one of my toughest days in a Formula 1 car."

He had thought he had a stomach bug but will now need surgery.

Bearman was in Jeddah competing in the Formula 2 championship and had taken pole position for the feature race in qualifying on Thursday.

'Bearman already marked out as potentially a special one'

Oliver Bearman joined the Ferrari Driver Academy aged 16 in November 2021

His appearance in the Ferrari will mark his full F1 debut, although he drove a Haas car in first practice at the Mexican and Abu Dhabi Grands Prix last year.

Lando Norris was previously the youngest Briton to race in F1 - taking part in practice for McLaren in Belgium in 2018 aged 18.

Ferrari have not said when Sainz will return to the cockpit.

In 2022, Williams driver Alex Albon missed the Italian Grand Prix with appendicitis and returned for the next race in Singapore.

The race after Saudi Arabia is the Australian Grand Prix in Melbourne on 20-22 March.'''

correct_triples = [
    # True Triples
    {"subject": "Carlos Sainz", "relation": "diagnosed_with", "object": "appendicitis"},
    {"subject": "Carlos Sainz", "relation": "will_miss", "object": "Saudi Arabian Grand Prix"},
    {"subject": "Oliver Bearman", "relation": "will_replace", "object": "Carlos Sainz at Jeddah"},
    {"subject": "Oliver Bearman", "relation": "age", "object": "18 years old"},
    {"subject": "Oliver Bearman", "relation": "to_become", "object": "youngest Briton to race in Formula 1"},
    {"subject": "Carlos Sainz", "relation": "had_been_unwell_for", "object": "two days"},
    {"subject": "Carlos Sainz", "relation": "thought_he_had", "object": "stomach bug"},
    {"subject": "Oliver Bearman", "relation": "was_competing_in", "object": "Formula 2 championship in Jeddah"},
    {"subject": "Oliver Bearman", "relation": "took_pole_position", "object": "for feature race"},
    {"subject": "Oliver Bearman", "relation": "joined", "object": "Ferrari Driver Academy in November 2021"},
    {"subject": "Oliver Bearman", "relation": "made_F1_debut", "object": "in Ferrari"},
    {"subject": "Lando Norris", "relation": "previously_youngest_Briton_to_race_in_F1", "object": "aged 18"},
    {"subject": "Alex Albon", "relation": "missed", "object": "Italian Grand Prix with appendicitis"},
    {"subject": "Alex Albon", "relation": "returned_for_next_race", "object": "in Singapore"},
]

incorrect_triples = [
    # False Triples
    {"subject": "Carlos Sainz", "relation": "diagnosed_with", "object": "stomach flu"},
    {"subject": "Oliver Bearman", "relation": "age", "object": "21 years old"},
    {"subject": "Carlos Sainz", "relation": "will_participate_in", "object": "Saudi Arabian Grand Prix"},
    {"subject": "Lando Norris", "relation": "made_F1_debut", "object": "in Ferrari"},
    {"subject": "Alex Albon", "relation": "returned_for_next_race", "object": "in Australia"},
    {"subject": "Oliver Bearman", "relation": "drove_a_Ferrari_car", "object": "in Formula 2"},
]

# %%
import sys
import os
sys.path.insert(0, '../knowledge_graph_validator')
os.environ['VALIDATION_MODEL'] = 'gpt-3.5-turbo-0125'
import validators

evaluator = validators.TextContextKGValidator
inp = {'triples': correct_triples + incorrect_triples, 'documents': [article]}

val = evaluator(**inp)
# Out:
# 100%|██████████| 20/20 [00:44<00:00,  2.23s/it]

# %%
print(val.model_dump_json(indent=2))
# Out:
# {
#   "triples": [
#     {
#       "subject": "Carlos Sainz",
#       "relation": "diagnosed_with",
#       "object": "appendicitis"
#     },
#     {
#       "subject": "Carlos Sainz",
#       "relation": "will_miss",
#       "object": "Saudi Arabian Grand Prix"
#     },
#     {
#       "subject": "Oliver Bearman",
#       "relation": "will_replace",
#       "object": "Carlos Sainz at Jeddah"
#     },
#     {
#       "subject": "Oliver Bearman",
#       "relation": "age",
#       "object": "18 years old"
#     },
#     {
#       "subject": "Oliver Bearman",
#       "relation": "to_become",
#       "object": "youngest Briton to race in Formula 1"
#     },
#     {
#       "subject": "Carlos Sainz",
#       "relation": "had_been_unwell_for",
#       "object": "two days"
#     },
#     {
#       "subject": "Carlos Sainz",
#       "relation": "thought_he_had",
#       "object": "stomach bug"
#     },
#     {
#       "subject": "Oliver Bearman",
#       "relation": "was_competing_in",
# ...
