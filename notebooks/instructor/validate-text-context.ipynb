# %%
from utils import read_jsonl, save_jsonl
import pandas as pd
from pydantic import BaseModel, model_validator, field_validator, Field, ValidationInfo
from typing import List, Dict, Union, Any, Optional
import instructor
from openai import OpenAI
import os
import json
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Chroma
from langchain_core.documents.base import Document
from langchain_openai import OpenAIEmbeddings

from data_classes import KnowledgeGraph, ValidatedProperty

# %%
client = instructor.patch(OpenAI(api_key=os.environ['OPENAI_API_KEY']))
MODEL = "gpt-3.5-turbo-0125"

# %% [markdown]
# # 🧠 Load data

# %%
pred_kbs = read_jsonl('../../data/prediction.jsonl')
ref_kbs = read_jsonl('../../data/wikidata_entities.jsonl')
print(f"Number of predicted KBs: {len(pred_kbs)}")
# Out:
# Number of predicted KBs: 4

# %%
ref_kbs[0].keys()
# Out:
# dict_keys(['entity_label', 'properties', 'chunked_content', 'QID'])

# %%
pred_kbs[0].keys()
# Out:
# dict_keys(['entity_label', 'properties'])

# %%
# only take the predictions and references of entities that exist in both
union_entities = set([p['entity_label'] for p in pred_kbs]).intersection(set([r['entity_label'] for r in ref_kbs]))

pred_kbs = [kb for kb in pred_kbs if kb['entity_label'] in union_entities]
pred_kbs = sorted(pred_kbs, key=lambda x: x['entity_label'])

ref_kbs = [kb for kb in ref_kbs if kb['entity_label'] in union_entities]
ref_kbs = sorted(ref_kbs, key=lambda x: x['entity_label'])

print(f"Number of predicted KBs: {len(pred_kbs)}")
print(f"Number of reference KBs: {len(ref_kbs)}")
print("ref: ", [kb['entity_label'] for kb in pred_kbs])
print("pred: ", [kb['entity_label'] for kb in ref_kbs])
# Out:
# Number of predicted KBs: 4
# Number of reference KBs: 4
# ref:  ['Barack Obama', 'Douglas Adams', 'George Washington', 'Tim Berners-Lee']
# pred:  ['Barack Obama', 'Douglas Adams', 'George Washington', 'Tim Berners-Lee']

# %% [markdown]
# # 🪬 Define Evaluation Model

# %%
class TextContextKGValidator(KnowledgeGraph):

    documents: List[str]
    validated_properties: List[ValidatedProperty] = []

    @staticmethod
    def create_parent_document_retriever(docs: List[Document]):
        # https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever

        # This text splitter is used to create the parent documents
        parent_splitter = RecursiveCharacterTextSplitter(chunk_size=2000)
        # This text splitter is used to create the child documents
        # It should create documents smaller than the parent
        child_splitter = RecursiveCharacterTextSplitter(chunk_size=400)
        # The vectorstore to use to index the child chunks
        vectorstore = Chroma(
            collection_name="full_documents", embedding_function=OpenAIEmbeddings()
        )
        # The storage layer for the parent documents
        store = InMemoryStore()
        retriever = ParentDocumentRetriever(
            vectorstore=vectorstore,
            docstore=store,
            child_splitter=child_splitter,
            parent_splitter=parent_splitter,
        )
        retriever.add_documents(docs, ids=None) # add entity doc(s)

        # list(store.yield_keys())   # see how many chunks it's created

        return retriever, store, vectorstore


    @staticmethod
    def retrieve_relevant_chunk(entity_name, property_name, vectorstore, retriever):
        '''Fetch the most similar chunk to entity label + predicted property name'''

        query = f"{entity_name} {property_name}"

        sub_docs = vectorstore.similarity_search(query)

        # if there is a parent doc chunk, use that, 
        #otherwise use the sub doc chunk
        parent_chunk = retriever.get_relevant_documents(query)
        if len(parent_chunk) > 0:
            relevant_chunk = parent_chunk[0].page_content
        else:
            relevant_chunk = sub_docs[0].page_content
        return relevant_chunk



    @model_validator(mode='before')
    def validate(self, context) -> "TextContextKGValidator":

        docs = [Document(d) for d in self['documents']]
        retriever, store, vectorstore = TextContextKGValidator.create_parent_document_retriever(docs)

        self['validated_properties'] = []
        existing_pred_properties = [name for name in self['properties'].keys()]

        for predicted_property_name, predicted_property_value in self['properties'].items():

            relevant_chunk = TextContextKGValidator.retrieve_relevant_chunk(
                entity_name=self['entity_label'],
                property_name=predicted_property_name, 
                vectorstore=vectorstore,
                retriever=retriever
            )

            # EVALUATE ONE PROPERTY
            resp: ValidatedProperty = client.chat.completions.create(
                response_model=ValidatedProperty,
                messages=[
                    {
                        "role": "user",
                        "content": f"Using your knowledge of the world " +
                        "and the given chunk of text, " +
                        "is the following property valid for the given entity? " +
                        f"\nEntity Label: {self['entity_label']}" +
                        f"\nPredicted Property Name: {predicted_property_name}" +
                        f"\nPredicted Property Value: {predicted_property_value}" +
                        f"\n\n{relevant_chunk}"
                    }
                ],
                validation_context={
                    "existing_pred_properties": existing_pred_properties,
                },
                max_retries=2,
                model=MODEL,
            )

            self['validated_properties'].append(resp)
        return self


    @model_validator(mode='after')
    def assert_all_properties_validated(self, info: ValidationInfo):
        if len(self.validated_properties) != len(self.properties):
            raise ValueError(
                "Number of properties validated does not match number of properties in the prediction knowledge base. " +
                f"Number of properties validated: {len(self.validated_properties)}, " +
                f"Number of properties in the text: {len(self.properties)}"
                )
        return self

# %% [markdown]
# # 🐕 Relevant Chunk Retrieval

# %%
idx = 0
results = []
assert pred_kbs[idx]['entity_label'] == ref_kbs[idx]['entity_label']
# joining the chunked content for each entity back together
docs = [" ".join([chunk for chunk in ref_kbs[idx]['chunked_content']])]  # 🚨 getting content from ref KG

pred_kbs[idx]['documents'] = docs

docs = [Document(d) for d in pred_kbs[idx]['documents']]
retriever, store, vectorstore = TextContextKGValidator.create_parent_document_retriever(docs)

retrieved_chunks = []
for predicted_property_name, predicted_property_value in pred_kbs[idx]['properties'].items():

    relevant_chunk = TextContextKGValidator.retrieve_relevant_chunk(
        entity_name=pred_kbs[idx]['entity_label'],
        property_name=predicted_property_name, 
        vectorstore=vectorstore,
        retriever=retriever
    )
    retrieved_chunks.append((predicted_property_name, predicted_property_value, relevant_chunk))

# %%
query = f"Barack Obama date of birth"
sub_docs = vectorstore.similarity_search(query)
sub_docs
# Out:
# [Document(page_content='Obama was born on August 4, 1961, at Kapiolani Medical Center for Women and Children in Honolulu, Hawaii. He is the only president born outside the contiguous 48 states. He was born to an American mother and a Kenyan father. His mother, Ann Dunham (1942–1995), was born in Wichita, Kansas and was of English, Welsh, German, Swiss, and Irish descent. In 2007 it was discovered her', metadata={'doc_id': '4e0001cc-59a2-46de-a8f8-0799232bbbc1'}),
# Obama met Trinity United Church of Christ pastor Jeremiah Wright in October 1987 and became a member of Trinity in 1992. During Obama's first presidential campaign in May 2008, he resigned from Trinity after some of Wright's statements were criticized. Since moving to Washington, D.C., in 2009, the Obama family has attended several Protestant churches, including Shiloh Baptist Church and St. John's Episcopal Church, as well as Evergreen Chapel at Camp David, but the members of the family do not attend church on a regular basis.In 2016, he said that he gets inspiration from a few items that remind him "of all the different people I've met along the way", adding: "I carry these around all the time. I'm not that superstitious, so it's not like I think I necessarily have to have them on me at all times." The items, "a whole bowl full", include rosary beads given to him by Pope Francis, a figurine of the Hindu deity Hanuman, a Coptic cross from Ethiopia, a small Buddha statue given by a monk, and a metal poker chip that used to be the lucky charm of a motorcyclist in Iowa.
#
#
# == Legal career ==
# 🙋Predicted value: ['Trinity United Church of Christ (1992-2008)', 'Shiloh Baptist Church', "St. John's Episcopal Church", 'Evergreen Chapel at Camp David']
#
# ----------
# ❓Property name: Law Firm
#  Relevant chunk -->  == Legal career ==
#
#
# === Civil rights attorney ===
# He joined Davis, Miner, Barnhill & Galland, a 13-attorney law firm specializing in civil rights litigation and neighborhood economic development, where he was an associate for three years from 1993 to 1996, then of counsel from 1996 to 2004. In 1994, he was listed as one of the lawyers in Buycks-Roberson v. Citibank Fed. Sav. Bank, 94 C 4094 (N.D. Ill.). This class action lawsuit was filed in 1994 with Selma Buycks-Roberson as lead plaintiff and alleged that Citibank Federal Savings Bank had engaged in practices forbidden under the Equal Credit Opportunity Act and the Fair Housing Act. The case was settled out of court.
# From 1994 to 2002, Obama served on the boards of directors of the Woods Fund of Chicago—which in 1985 had been the first foundation to fund the Developing Communities Project—and of the Joyce Foundation. He served on the board of directors of the Chicago Annenberg Challenge from 1995 to 2002, as founding president and chairman of the board of directors from 1995 to 1999. Obama's law license became inactive in 2007.
#
#
# == Legislative career ==
#
#
# === Illinois Senate (1997–2004) ===
# 🙋Predicted value: Davis, Miner, Barnhill & Galland (1993-2004)
#
# ----------
# ❓Property name: Board Memberships
#  Relevant chunk -->  == Legal career ==
#
#
# === Civil rights attorney ===
# He joined Davis, Miner, Barnhill & Galland, a 13-attorney law firm specializing in civil rights litigation and neighborhood economic development, where he was an associate for three years from 1993 to 1996, then of counsel from 1996 to 2004. In 1994, he was listed as one of the lawyers in Buycks-Roberson v. Citibank Fed. Sav. Bank, 94 C 4094 (N.D. Ill.). This class action lawsuit was filed in 1994 with Selma Buycks-Roberson as lead plaintiff and alleged that Citibank Federal Savings Bank had engaged in practices forbidden under the Equal Credit Opportunity Act and the Fair Housing Act. The case was settled out of court.
# From 1994 to 2002, Obama served on the boards of directors of the Woods Fund of Chicago—which in 1985 had been the first foundation to fund the Developing Communities Project—and of the Joyce Foundation. He served on the board of directors of the Chicago Annenberg Challenge from 1995 to 2002, as founding president and chairman of the board of directors from 1995 to 1999. Obama's law license became inactive in 2007.
#
#
# == Legislative career ==
#
#
# === Illinois Senate (1997–2004) ===
# 🙋Predicted value: ['Woods Fund of Chicago (1994-2002)', 'Joyce Foundation (1994-2002)', 'Chicago Annenberg Challenge (1995-2002)']
#
# ----------
# ❓Property name: Illinois Senate Period
#  Relevant chunk -->  == Legislative career ==
#
#
# === Illinois Senate (1997–2004) ===
#
# Immigration Reform and Control Act of 1986
# IRS targeting controversy
# Middle Class Tax Relief and Job Creation Act of 2012
# National Broadband Plan (United States)
# Office of Energy Efficiency and Renewable Energy
# Social policy of the Barack Obama administration
# SPEECH Act
# Stay with It
# White House Office of Energy and Climate Change Policy
#
#
# === Other ===
# Roberts Court
# Speeches of Barack Obama
#
#
# === Lists ===
# Assassination threats against Barack Obama
# List of African-American United States senators
# List of Barack Obama 2008 presidential campaign endorsements
# List of Barack Obama 2012 presidential campaign endorsements
# List of federal political scandals, 2009–17
# List of people granted executive clemency by Barack Obama
# List of things named after Barack Obama
#
#
# == References ==
#
#
# === Bibliography ===
#
#
# == Further reading ==
#
#
# == External links ==
# 🙋Predicted value: The Barack Obama Presidential Center will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.
#
# ----------
# ❓Property name: Awards and Honors
#  Relevant chunk -->  === Presidential library ===
#
# The Barack Obama Presidential Center is Obama's planned presidential library. It will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.
#
#
# === Awards and honors ===
#
# Obama received the Norwegian Nobel Committee's Nobel Peace Prize in 2009, The Shoah Foundation Institute for Visual History and Education's Ambassador of Humanity Award in 2014, the John F. Kennedy Profile in Courage Award in 2017, and the Robert F. Kennedy Center for Justice and Human Rights Ripple of Hope Award in 2018. He was named TIME Magazine's Time Person of the Year in 2008 and 2012. He also received two Grammy Awards for Best Spoken Word Album for Dreams from My Father (2006), and The Audacity of Hope (2008) as well as two Primetime Emmy Awards for Outstanding Narrator for Our Great National Parks (2022), and Working: What We Do All Day (2023). He also won two Children's and Family Emmy Awards.
#
#
# == Bibliography ==
#
#
# == See also ==
#
#
# === Politics ===
# DREAM Act
# Fraud Enforcement and Recovery Act of 2009
# Immigration Reform and Control Act of 1986
# IRS targeting controversy
# Middle Class Tax Relief and Job Creation Act of 2012
# National Broadband Plan (United States)
# Office of Energy Efficiency and Renewable Energy
# Social policy of the Barack Obama administration
# SPEECH Act
# Stay with It
# White House Office of Energy and Climate Change Policy
#
#
# === Other ===
# Roberts Court
# Speeches of Barack Obama
#
#
# === Lists ===
# Assassination threats against Barack Obama
# List of African-American United States senators
# List of Barack Obama 2008 presidential campaign endorsements
# List of Barack Obama 2012 presidential campaign endorsements
# List of federal political scandals, 2009–17
# List of people granted executive clemency by Barack Obama
# List of things named after Barack Obama
#
#
# == References ==
#
#
# === Bibliography ===
#
#
# == Further reading ==
#
#
# == External links ==
# 🙋Predicted value: ['Nobel Peace Prize in 2009', 'Ambassador of Humanity Award in 2014', 'Profile in Courage Award in 2017', 'Ripple of Hope Award in 2018', 'Time Person of the Year in 2008 and 2012', 'Two Grammy Awards for Best Spoken Word Album', 'Two Primetime Emmy Awards for Outstanding Narrator', "Two Children's and Family Emmy Awards"]
#
# ----------
# ❓Property name: Bought Stocks in
pred_kbs[idx]['properties']['Bought Stocks in'] = ['Tesla', 'Nvidia', 'Hertz']
pred_kbs[idx]['properties']['Favourite Fast Food Chain'] = 'McDonalds'

results.append(TextContextKGValidator(**pred_kbs[idx]))

# %%
results[0].model_dump()['validated_properties']
# Out:
# [{'property_name': 'Birth Place',
#   'property_value': 'Honolulu, Hawaii',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama was indeed born in Honolulu, Hawaii at the Kapiolani Medical Center for Women and Children.',
#   'error_message': None},
#  {'property_name': 'Birthday',
#   'property_value': 'August 4, 1961',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama was born on August 4, 1961, as mentioned in the text.',
#   'error_message': None},
#  {'property_name': 'Party',
#   'property_value': 'Democratic Party',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama is indeed a member of the Democratic Party, which is supported by the given information about his political affiliations and role as the 44th president of the United States.',
#   'error_message': None},
#  {'property_name': 'Education',
#   'property_value': ['Columbia University',
#    'Harvard Law School',
#    'Occidental College'],
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama graduated from Columbia University in 1983 with a B.A. in political science and later enrolled in Harvard Law School, where he became the first black president of the Harvard Law Review.',
#   'error_message': None},
#  {'property_name': 'Net Worth in 2007',
#   'property_value': '$1.3 million (equivalent to $1.8 million in 2022)',
#   'property_is_valid': True,
#   'is_valid_reason': "The property value of $1.3 million in 2007 is consistent with the information provided in the text, which states that Money Magazine estimated Obama's net worth at $1.3 million in December 2007.",
#   'error_message': None},
#  {'property_name': 'House Purchase in 2005',
#   'property_value': '$1.6 million house in Kenwood, Chicago (equivalent to $2.4 million in 2022)',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property value of $1.6 million house in Kenwood, Chicago is correct as described in the text. The equivalent value in 2022 is also provided, showing a valid comparison.',
#   'error_message': None},
#  {'property_name': 'Income in 2009',
#   'property_value': '$5.5 million',
#   'property_is_valid': True,
#   'is_valid_reason': 'The predicted property value matches the reported household income of $5.5 million in 2009 as per the text provided for Barack Obama.',
#   'error_message': None},
#  {'property_name': 'Charitable Donation in 2010',
#   'property_value': '$131,000 to Fisher House Foundation',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property value of $131,000 is accurately mentioned in the text as a charitable donation made by Barack Obama in 2010 to the Fisher House Foundation.',
#   'error_message': None},
#  {'property_name': 'Religious Views',
#   'property_value': 'Protestant Christian, described his religious beliefs and journey in The Audacity of Hope',
#   'property_is_valid': True,
#   'is_valid_reason': "The property value accurately describes Barack Obama's religious views as a Protestant Christian, and it is supported by the provided text from The Audacity of Hope.",
#   'error_message': None},
#  {'property_name': 'Church Affiliations',
#   'property_value': ['Trinity United Church of Christ (1992-2008)',
#    'Shiloh Baptist Church',
#    "St. John's Episcopal Church",
#    'Evergreen Chapel at Camp David'],
#   'property_is_valid': True,
#   'is_valid_reason': "Barack Obama has been affiliated with Trinity United Church of Christ, Shiloh Baptist Church, St. John's Episcopal Church, and Evergreen Chapel at Camp David at different points in his life and career.",
#   'error_message': None},
#  {'property_name': 'Law Firm',
#   'property_value': 'Davis, Miner, Barnhill & Galland (1993-2004)',
#   'property_is_valid': True,
#   'is_valid_reason': "The property value matches the information provided in the text about Barack Obama's legal career at the law firm Davis, Miner, Barnhill & Galland from 1993 to 2004.",
#   'error_message': None},
#  {'property_name': 'Board Memberships',
#   'property_value': ['Woods Fund of Chicago (1994-2002)',
#    'Joyce Foundation (1994-2002)',
#    'Chicago Annenberg Challenge (1995-2002)'],
#   'property_is_valid': True,
#   'is_valid_reason': "The property 'Board Memberships' matches the information provided in the text related to Barack Obama's involvement in the Woods Fund of Chicago, Joyce Foundation, and Chicago Annenberg Challenge boards from 1994 to 2002.",
#   'error_message': None},
#  {'property_name': 'Illinois Senate Period',
#   'property_value': '1996-2004',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property value matches the period during which Barack Obama served in the Illinois Senate from 1996 to 2004.',
#   'error_message': None},
#  {'property_name': 'Legislation Sponsored',
#   'property_value': ['Ethics and health care laws reform',
#    'Increased tax credits for low-income workers',
#    'Welfare reform and increased subsidies for childcare',
#    'Legislation to monitor racial profiling and mandate videotaping of homicide interrogations',
#    'Death penalty reforms, Iran Sanctions Enabling Act, and others'],
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama sponsored a range of legislation during his time as a senator, including the Iran Sanctions Enabling Act, various healthcare and welfare reforms, and legislation on racial profiling and homicide interrogations.',
#   'error_message': None},
#  {'property_name': 'U.S. Senate Period',
#   'property_value': '2005-2008',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama did serve as a U.S. senator representing Illinois from 2005 to 2008, according to the provided text.',
#   'error_message': None},
#  {'property_name': 'Initiatives Introduced',
#   'property_value': ['Lugar–Obama (Nunn–Lugar Cooperative Threat Reduction concept)',
#    'Federal Funding Accountability and Transparency Act of 2006',
#    'Strengthening Transparency and Accountability in Federal Spending Act of 2008'],
#   'property_is_valid': True,
#   'is_valid_reason': "The property 'Initiatives Introduced' is valid for the entity 'Barack Obama' as he introduced the mentioned initiatives during his time as a senator. The text provided confirms the introduction of these initiatives by Barack Obama.",
#   'error_message': None},
#  {'property_name': 'Legislation Sponsored in Senate',
#   'property_value': ['Democratic Republic of the Congo Relief, Security, and Democracy Promotion Act',
#    'Corporate jet provision to Honest Leadership and Open Government Act',
#    'Amendment to Defense Authorization Act for safeguarding personality-disorder military discharges',
#    "State Children's Health Insurance Program amendment",
#    'Various foreign relations and homeland security related legislation'],
#   'property_is_valid': True,
#   'is_valid_reason': "The text mentions multiple pieces of legislation sponsored by Barack Obama during his time in the Senate, including the Democratic Republic of the Congo Relief, Security, and Democracy Promotion Act, Corporate jet provision to Honest Leadership and Open Government Act, Amendment to Defense Authorization Act for safeguarding personality-disorder military discharges, State Children's Health Insurance Program amendment, and various foreign relations and homeland security related legislation.",
#   'error_message': None},
#  {'property_name': 'Presidential Campaigns',
#   'property_value': ['2008: Won the presidency with 365 electoral votes, first African-American to be elected president',
#    '2012: Reelected as president'],
#   'property_is_valid': True,
#   'is_valid_reason': "The property value accurately describes Barack Obama's presidential campaigns in 2008 and 2012, providing specific details of his victories and achievements during those years.",
#   'error_message': None},
#  {'property_name': 'Electoral Votes in 2012',
#   'property_value': 332,
#   'property_is_valid': True,
#   'is_valid_reason': 'The property value matches the actual number of electoral votes obtained by Barack Obama in the 2012 election.',
#   'error_message': None},
#  {'property_name': 'Popular Vote Percentage in 2012',
#   'property_value': '51.1%',
#   'property_is_valid': True,
#   'is_valid_reason': "The property value '51.1%' represents the popular vote percentage obtained by Barack Obama in the 2012 election, as mentioned in the provided text.",
#   'error_message': None},
#  {'property_name': 'First Democratic President since FDR to Win Majority of Popular Vote Twice',
#   'property_value': True,
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama won the majority of the popular vote twice, making him the first Democratic president since Franklin D. Roosevelt to achieve this feat.',
#   'error_message': None},
#  {'property_name': 'Reelection Address Location',
#   'property_value': "Chicago's McCormick Place",
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "Barack Obama did not have a reelection as President of the United States. Therefore, the property 'Reelection Address Location' is not valid for him."},
#  {'property_name': 'Free Trade Pact Advocated',
#   'property_value': 'Trans-Pacific Partnership',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The provided information does not contain any mention of Barack Obama advocating for the Trans-Pacific Partnership. Therefore, the predicted property 'Free Trade Pact Advocated' with the value 'Trans-Pacific Partnership' is not valid for Barack Obama."},
#  {'property_name': 'Environmental Policy Actions',
#   'property_value': ['Established a federal investigation after the Macondo Prospect oil leak',
#    'Announced a six-month moratorium on new deepwater drilling permits and leases',
#    'Permanently banned new offshore oil and gas drilling in most U.S.-owned waters in the Atlantic and Arctic Oceans',
#    'Created 25 new national monuments and expanded four others under the Antiquities Act'],
#   'property_is_valid': True,
#   'is_valid_reason': 'The provided Environmental Policy Actions align with actions taken by Barack Obama during his presidency to combat climate change and preserve environmental resources.',
#   'error_message': None},
#  {'property_name': 'Environmental Policy Land Protection',
#   'property_value': 'Protected a total of 553,000,000 acres of federal lands and waters',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama emphasized the conservation of federal lands during his term in office and used his power under the Antiquities Act to create national monuments and expand others, protecting a total of 553,000,000 acres of federal lands and waters.',
#   'error_message': None},
#  {'property_name': 'United Nations Resolution on Israeli Settlements (2011)',
#   'property_value': 'Vetoed a Security Council resolution condemning Israeli settlements in 2011, with the United States being the only nation to do so',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property value aligns with the provided information indicating that in 2011, the United States, under the Obama administration, indeed vetoed a Security Council resolution condemning Israeli settlements, with the U.S. being the only nation to do so.',
#   'error_message': None},
#  {'property_name': 'Support for Two-State Solution',
#   'property_value': 'Supports the two-state solution to the Arab–Israeli conflict based on the 1967 borders with land swaps',
#   'property_is_valid': True,
#   'is_valid_reason': "Barack Obama's public stance and actions indicate support for the two-state solution as described",
#   'error_message': None},
#  {'property_name': 'Comparison of Zionist Movement to Civil Rights Movement',
#   'property_value': 'Likened the Zionist movement to the civil rights movement in the United States in 2014, stating that both seek to bring justice and equal rights to historically persecuted peoples',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama did liken the Zionist movement to the civil rights movement in the United States in 2014, expressing that both seek justice and equal rights for historically persecuted peoples.',
#   'error_message': None},
#  {'property_name': "Support for Israel's Right to Defend Itself",
#   'property_value': "Expressed support for Israel's right to defend itself during the 2014 Israel–Gaza conflict",
#   'property_is_valid': True,
#   'is_valid_reason': "Barack Obama expressed support for Israel's right to defend itself during the 2014 Israel–Gaza conflict, as mentioned in the provided text. This aligns with his actions and statements regarding Israel's defense and security concerns.",
#   'error_message': None},
#  {'property_name': 'United Nations Resolution 2334 Abstention',
#   'property_value': 'Under the Obama Administration, the United States abstained from United Nations Security Council Resolution 2334 in 2016, allowing it to pass and condemning Israeli settlement building in the occupied Palestinian territories',
#   'property_is_valid': True,
#   'is_valid_reason': "The property accurately describes the stance of the United States and Barack Obama's administration on United Nations Resolution 2334.",
#   'error_message': None},
#  {'property_name': 'Presidential Library',
#   'property_value': 'The Barack Obama Presidential Center will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property is valid as it accurately describes the planned Barack Obama Presidential Center.',
#   'error_message': None},
#  {'property_name': 'Awards and Honors',
#   'property_value': ['Nobel Peace Prize in 2009',
#    'Ambassador of Humanity Award in 2014',
#    'Profile in Courage Award in 2017',
#    'Ripple of Hope Award in 2018',
#    'Time Person of the Year in 2008 and 2012',
#    'Two Grammy Awards for Best Spoken Word Album',
#    'Two Primetime Emmy Awards for Outstanding Narrator',
#    "Two Children's and Family Emmy Awards"],
#   'property_is_valid': True,
#   'is_valid_reason': 'The predicted property value matches the awards and honors received by Barack Obama as listed in the text.',
#   'error_message': None},
#  {'property_name': 'Bought Stocks in',
#   'property_value': ['Tesla', 'Nvidia', 'Hertz'],
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': 'There is no evidence or information provided that Barack Obama bought stocks in Tesla, Nvidia, or Hertz. The text only mentions his educational and professional background, community organizing work, and travels to Indonesia, Pakistan, Europe, and Kenya, but it does not mention any stock investments.'},
#  {'property_name': 'Favourite Fast Food Chain',
#   'property_value': 'McDonalds',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "There is no information provided in the text indicating Barack Obama's favourite fast food chain. Therefore, the property 'Favourite Fast Food Chain' with the value 'McDonalds' is invalid for the entity Barack Obama."}]

# %%
results_json = [r.model_dump() for r in results]
save_jsonl(results_json, '../../data/text_context_evaluation_results.jsonl')
# Out:
# Saved to f'../../data/text_context_evaluation_results.jsonl

# %% [markdown]
# # Look at our Evaluations

# %%
results = read_jsonl('../../data/text_context_evaluation_results.jsonl')
len(results)
# Out:
# 1
