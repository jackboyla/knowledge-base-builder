# %%
from utils import read_jsonl, save_jsonl
import pandas as pd
from pydantic import BaseModel, model_validator, field_validator, Field, ValidationInfo
from typing import List, Dict, Union, Any, Optional
import instructor
from openai import OpenAI
import os
import json
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Chroma
from langchain_core.documents.base import Document
from langchain_openai import OpenAIEmbeddings

from data_classes import KnowledgeGraph, ValidatedProperty

# %%
client = instructor.patch(OpenAI(api_key=os.environ['OPENAI_API_KEY']))
MODEL = "gpt-3.5-turbo-0125"

# %% [markdown]
# # 🧠 Load data

# %%
pred_kbs = read_jsonl('../../data/prediction.jsonl')
ref_kbs = read_jsonl('../../data/wikidata_entities.jsonl')
print(f"Number of predicted KBs: {len(pred_kbs)}")
# Out:
# Number of predicted KBs: 4

# %%
ref_kbs[0].keys()
# Out:
# dict_keys(['entity_label', 'properties', 'chunked_content', 'QID'])

# %%
pred_kbs[0].keys()
# Out:
# dict_keys(['entity_label', 'properties'])

# %%
# only take the predictions and references of entities that exist in both
union_entities = set([p['entity_label'] for p in pred_kbs]).intersection(set([r['entity_label'] for r in ref_kbs]))

pred_kbs = [kb for kb in pred_kbs if kb['entity_label'] in union_entities]
pred_kbs = sorted(pred_kbs, key=lambda x: x['entity_label'])

ref_kbs = [kb for kb in ref_kbs if kb['entity_label'] in union_entities]
ref_kbs = sorted(ref_kbs, key=lambda x: x['entity_label'])

print(f"Number of predicted KBs: {len(pred_kbs)}")
print(f"Number of reference KBs: {len(ref_kbs)}")
print("ref: ", [kb['entity_label'] for kb in pred_kbs])
print("pred: ", [kb['entity_label'] for kb in ref_kbs])
# Out:
# Number of predicted KBs: 4
# Number of reference KBs: 4
# ref:  ['Barack Obama', 'Douglas Adams', 'George Washington', 'Tim Berners-Lee']
# pred:  ['Barack Obama', 'Douglas Adams', 'George Washington', 'Tim Berners-Lee']

# %% [markdown]
# # 🪬 Define Evaluation Model

# %%
class ReferenceKGValidator(KnowledgeGraph):

    reference_wikidata_knowledge_graph: KnowledgeGraph = None
    validated_properties: List[ValidatedProperty] = []


    @staticmethod
    def create_parent_document_retriever(docs: List[Document]):
        # https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever

        # This text splitter is used to create the child documents
        child_splitter = RecursiveCharacterTextSplitter(chunk_size=400)
        # The vectorstore to use to index the child chunks
        vectorstore = Chroma(
            collection_name="full_documents", embedding_function=OpenAIEmbeddings()
        )
        # The storage layer for the parent documents
        store = InMemoryStore()
        retriever = ParentDocumentRetriever(
            vectorstore=vectorstore,
            docstore=store,
            child_splitter=child_splitter,
            # parent_splitter=parent_splitter,
        )
        retriever.add_documents(docs, ids=None) # add entity doc(s)

        # list(store.yield_keys())   # see how many chunks it's created

        return retriever, store, vectorstore


    @staticmethod
    def retrieve_relevant_property(entity_name, property_name, vectorstore, retriever):
        '''Fetch the most similar chunk to predicted property name'''

        query = f"{property_name}"

        sub_docs = vectorstore.similarity_search(query)

        # if there is a parent doc chunk, use that, 
        #otherwise use the sub doc chunk
        parent_chunk = retriever.get_relevant_documents(query)
        if len(parent_chunk) > 0:
            relevant_property = parent_chunk[0].page_content
        else:
            relevant_property = sub_docs[0].page_content
        return relevant_property



    @model_validator(mode='before')
    def validate(self, context) -> "ReferenceKGValidator":

        ref_property_names = [Document(p) for p in self['reference_knowledge_graph']['properties'].keys()]   # 🚨 embedding the reference properties
        retriever, store, vectorstore = ReferenceKGValidator.create_parent_document_retriever(ref_property_names)

        self['validated_properties'] = []
        existing_pred_properties = [name for name in self['properties'].keys()]

        for predicted_property_name, predicted_property_value in self['properties'].items():

            relevant_property_name = ReferenceKGValidator.retrieve_relevant_property(
                entity_name=self['entity_label'],
                property_name=predicted_property_name, 
                vectorstore=vectorstore,
                retriever=retriever
            )
            # get reference property-value pairs
            relevant_property = {
                relevant_property_name: self['reference_knowledge_graph']['properties'][relevant_property_name]
            }

            # EVALUATE ONE PROPERTY
            resp: ValidatedProperty = client.chat.completions.create(
                response_model=ValidatedProperty,
                messages=[
                    {
                        "role": "user",
                        "content": f"Using your knowledge of the world " +
                        "and the given candidate property from the reference knowledge graph, " +
                        "is the following predicted property valid for the given entity? " +
                        f"\nEntity Label: {self['entity_label']}" +
                        f"\nPredicted Property Name: {predicted_property_name}" +
                        f"\nPredicted Property Value: {predicted_property_value}" +
                        f"\n\nReference Properties {relevant_property}"
                    }
                ],
                validation_context={
                    "existing_pred_properties": existing_pred_properties,
                },
                max_retries=2,
                model=MODEL,
            )

            self['validated_properties'].append(resp)
        return self


    @model_validator(mode='after')
    def assert_all_properties_validated(self, info: ValidationInfo):
        if len(self.validated_properties) != len(self.properties):
            raise ValueError(
                "Number of properties validated does not match number of properties in the prediction knowledge base. " +
                f"Number of properties validated: {len(self.validated_properties)}, " +
                f"Number of properties in the text: {len(self.properties)}"
                )
        return self

# %% [markdown]
# # 🐕 Relevant Chunk Retrieval

# %%
idx = 0
results = []
assert pred_kbs[idx]['entity_label'] == ref_kbs[idx]['entity_label']

pred_kbs[idx]['reference_knowledge_graph'] = ref_kbs[idx]

ref_property_names = [Document(p) for p in ref_kbs[idx]['properties'].keys()]   # 🚨 embedding the reference properties
retriever, store, vectorstore = ReferenceKGValidator.create_parent_document_retriever(ref_property_names)

retrieved_properties = []
for predicted_property_name, predicted_property_value in pred_kbs[idx]['properties'].items():

    relevant_property_name = ReferenceKGValidator.retrieve_relevant_property(
        entity_name=pred_kbs[idx]['entity_label'],
        property_name=predicted_property_name, 
        vectorstore=vectorstore,
        retriever=retriever
    )

    # # get reference property-value
    relevant_property = {
        relevant_property_name: pred_kbs[idx]['reference_knowledge_graph']['properties'][relevant_property_name]
    }
    retrieved_properties.append((predicted_property_name, predicted_property_value, relevant_property))
    print((predicted_property_name, predicted_property_value, relevant_property))
# Out:
# ('Birth Place', 'Honolulu, Hawaii', {'place of birth': ['Kapiolani Medical Center for Women and Children', 'Honolulu']})
# ('Birthday', 'August 4, 1961', {'date of birth': ['+1961-08-04T00:00:00Z']})
# ('Party', 'Democratic Party', {'occupation': ['politician', 'lawyer', 'political writer', 'community organizer', 'statesperson', 'jurist', 'podcaster', 'academic', 'memoirist', 'international forum participant']})
# ('Education', ['Columbia University', 'Harvard Law School', 'Occidental College'], {'educated at': ['State Elementary School Menteng 01', 'Punahou School', 'Occidental College', 'Columbia University', 'Harvard Law School', 'Noelani Elementary School', 'Centaurus High School', 'University of Chicago Law School', 'Harvard University', 'Nelson High School', 'King College Prep High School']})
# ('Net Worth in 2007', '$1.3 million (equivalent to $1.8 million in 2022)', {'NLP ID (old)': ['a0000002122644']})
# ('House Purchase in 2005', '$1.6 million house in Kenwood, Chicago (equivalent to $2.4 million in 2022)', {'father': ['Barack Obama Sr.']})
# ('Income in 2009', '$5.5 million', {'employer': ['Business International Corporation', 'New York Public Interest Research Group', 'Gamaliel Foundation', 'Sidley Austin', 'University of Chicago']})
# ('Charitable Donation in 2010', '$131,000 to Fisher House Foundation', {'award received': ['Nobel Peace Prize', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'Presidential Medal of Distinction', 'Time Person of the Year', 'Time Person of the Year', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction', "NAACP Image Award – Chairman's Award", 'German Media Award', 'King Abdulaziz Medal', 'Order of Sikatuna', 'National Medal of Science', 'honorary doctorate from the University of Notre Dame', 'honorary doctor of the Northwestern University', 'honorary doctor of the University of Johannesburg', 'Order of the Rajamitrabhorn', 'Knight Commander of the Order of the British Empire', 'Romy', 'Primetime Emmy Award for Outstanding Narrator', 'Financial Times Person of the Year', 'Phoenix Award', 'Audie Award for Narration by the Author', 'Profile in Courage Award']})
# ('Religious Views', 'Protestant Christian, described his religious beliefs and journey in The Audacity of Hope', {'Reddit username': ['PresidentObama']})
# ('Church Affiliations', ['Trinity United Church of Christ (1992-2008)', 'Shiloh Baptist Church', "St. John's Episcopal Church", 'Evergreen Chapel at Camp David'], {'archives at': ['Stuart A. Rose Manuscript, Archives, and Rare Book Library']})
# ('Law Firm', 'Davis, Miner, Barnhill & Galland (1993-2004)', {'employer': ['Business International Corporation', 'New York Public Interest Research Group', 'Gamaliel Foundation', 'Sidley Austin', 'University of Chicago']})
# ('Board Memberships', ['Woods Fund of Chicago (1994-2002)', 'Joyce Foundation (1994-2002)', 'Chicago Annenberg Challenge (1995-2002)'], {'member of': ['American Academy of Arts and Sciences', 'American Philosophical Society', '109th United States Congress', '110th United States Congress', 'Congressional Black Caucus']})
# ('Illinois Senate Period', '1996-2004', {'LittleSis people ID': ['13503']})
# ('Legislation Sponsored', ['Ethics and health care laws reform', 'Increased tax credits for low-income workers', 'Welfare reform and increased subsidies for childcare', 'Legislation to monitor racial profiling and mandate videotaping of homicide interrogations', 'Death penalty reforms, Iran Sanctions Enabling Act, and others'], {'nominated for': ['Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction']})
# ('U.S. Senate Period', '2005-2008', {'United States House of Representatives ID': ['19276']})
# ('Initiatives Introduced', ['Lugar–Obama (Nunn–Lugar Cooperative Threat Reduction concept)', 'Federal Funding Accountability and Transparency Act of 2006', 'Strengthening Transparency and Accountability in Federal Spending Act of 2008'], {'Our Campaigns candidate ID': ['4577']})
# ('Legislation Sponsored in Senate', ['Democratic Republic of the Congo Relief, Security, and Democracy Promotion Act', 'Corporate jet provision to Honest Leadership and Open Government Act', 'Amendment to Defense Authorization Act for safeguarding personality-disorder military discharges', "State Children's Health Insurance Program amendment", 'Various foreign relations and homeland security related legislation'], {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']})
# ('Presidential Campaigns', ['2008: Won the presidency with 365 electoral votes, first African-American to be elected president', '2012: Reelected as president'], {'Our Campaigns candidate ID': ['4577']})
# ('Electoral Votes in 2012', 332, {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']})
# ('Popular Vote Percentage in 2012', '51.1%', {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']})
# ('First Democratic President since FDR to Win Majority of Popular Vote Twice', 'True', {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']})
# ('Reelection Address Location', "Chicago's McCormick Place", {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']})
# ('Free Trade Pact Advocated', 'Trans-Pacific Partnership', {'political ideology': ['feminism', 'gun control']})
# ('Environmental Policy Actions', ['Established a federal investigation after the Macondo Prospect oil leak', 'Announced a six-month moratorium on new deepwater drilling permits and leases', 'Permanently banned new offshore oil and gas drilling in most U.S.-owned waters in the Atlantic and Arctic Oceans', 'Created 25 new national monuments and expanded four others under the Antiquities Act'], {'political ideology': ['feminism', 'gun control']})
# ('Environmental Policy Land Protection', 'Protected a total of 553,000,000 acres of federal lands and waters', {'political ideology': ['feminism', 'gun control']})
# ('United Nations Resolution on Israeli Settlements (2011)', 'Vetoed a Security Council resolution condemning Israeli settlements in 2011, with the United States being the only nation to do so', {'National Library of Israel J9U ID': ['987007304957705171']})
# ('Support for Two-State Solution', 'Supports the two-state solution to the Arab–Israeli conflict based on the 1967 borders with land swaps', {'described at URL': ["http://www.treccani.it/enciclopedia/barack-obama_(Il-Libro-dell'Anno)/", 'https://www.whitehouse.gov/about-the-white-house/presidents/barack-obama/']})
# ('Comparison of Zionist Movement to Civil Rights Movement', 'Likened the Zionist movement to the civil rights movement in the United States in 2014, stating that both seek to bring justice and equal rights to historically persecuted peoples', {'political ideology': ['feminism', 'gun control']})
# ("Support for Israel's Right to Defend Itself", "Expressed support for Israel's right to defend itself during the 2014 Israel–Gaza conflict", {'National Library of Israel J9U ID': ['987007304957705171']})
# ('United Nations Resolution 2334 Abstention', 'Under the Obama Administration, the United States abstained from United Nations Security Council Resolution 2334 in 2016, allowing it to pass and condemning Israeli settlement building in the occupied Palestinian territories', {'IdRef ID': ['118177257']})
# ('Presidential Library', 'The Barack Obama Presidential Center will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.', {'National Library of Israel J9U ID': ['987007304957705171']})
# ('Awards and Honors', ['Nobel Peace Prize in 2009', 'Ambassador of Humanity Award in 2014', 'Profile in Courage Award in 2017', 'Ripple of Hope Award in 2018', 'Time Person of the Year in 2008 and 2012', 'Two Grammy Awards for Best Spoken Word Album', 'Two Primetime Emmy Awards for Outstanding Narrator', "Two Children's and Family Emmy Awards"], {'award received': ['Nobel Peace Prize', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'Presidential Medal of Distinction', 'Time Person of the Year', 'Time Person of the Year', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction', "NAACP Image Award – Chairman's Award", 'German Media Award', 'King Abdulaziz Medal', 'Order of Sikatuna', 'National Medal of Science', 'honorary doctorate from the University of Notre Dame', 'honorary doctor of the Northwestern University', 'honorary doctor of the University of Johannesburg', 'Order of the Rajamitrabhorn', 'Knight Commander of the Order of the British Empire', 'Romy', 'Primetime Emmy Award for Outstanding Narrator', 'Financial Times Person of the Year', 'Phoenix Award', 'Audie Award for Narration by the Author', 'Profile in Courage Award']})
# ('Bought Stocks in', ['Tesla', 'Nvidia', 'Hertz'], {'participant in': ['commencement at the Knox College', 'commencement at the University of Notre Dame', 'World Government Summit 2016']})
# ('Favourite Fast Food Chain', 'McDonalds', {'InfluenceWatch influencer': ['person/barack-obama']})

# %%
relevant_property = ReferenceKGValidator.retrieve_relevant_property(
    entity_name="Barack Obama",
    property_name='Job', 
    vectorstore=vectorstore,
    retriever=retriever
)
relevant_property
# Out:
# 'occupation'

# %%
query = f"Barack Obama date of birth"
sub_docs = vectorstore.similarity_search(query)
sub_docs
# Out:
# [Document(page_content='date of birth', metadata={'doc_id': '31a1b64e-c332-4ca3-a2ca-3672c69904ae'}),
#  Document(page_content='date of birth', metadata={'doc_id': 'cd14cb0b-ec12-44c8-9058-d8724ef2fb51'}),
#  Document(page_content='date of birth', metadata={'doc_id': 'b6d49bed-b6b8-4101-8a80-d7278b4d9823'}),
#  Document(page_content='date of birth', metadata={'doc_id': '65572c63-ac5e-4dfd-bee4-8c3f46eadedd'})]

# %%
for predicted_property_name, predicted_property_value, relevant_property in retrieved_properties:
    print(f"\n----------\n❓Pred Property name: {predicted_property_name}\n🙋Predicted value: {predicted_property_value}\n⭐️ Relevant property -->  {relevant_property}\n")
# Out:
# ----------
# ❓Pred Property name: Birth Place
# 🙋Predicted value: Honolulu, Hawaii
# ⭐️ Relevant property -->  {'place of birth': ['Kapiolani Medical Center for Women and Children', 'Honolulu']}
#
#
# ----------
# ❓Pred Property name: Birthday
# 🙋Predicted value: August 4, 1961
# ⭐️ Relevant property -->  {'date of birth': ['+1961-08-04T00:00:00Z']}
#
#
# ----------
# ❓Pred Property name: Party
# 🙋Predicted value: Democratic Party
# ⭐️ Relevant property -->  {'occupation': ['politician', 'lawyer', 'political writer', 'community organizer', 'statesperson', 'jurist', 'podcaster', 'academic', 'memoirist', 'international forum participant']}
#
#
# ----------
# ❓Pred Property name: Education
# 🙋Predicted value: ['Columbia University', 'Harvard Law School', 'Occidental College']
# ⭐️ Relevant property -->  {'educated at': ['State Elementary School Menteng 01', 'Punahou School', 'Occidental College', 'Columbia University', 'Harvard Law School', 'Noelani Elementary School', 'Centaurus High School', 'University of Chicago Law School', 'Harvard University', 'Nelson High School', 'King College Prep High School']}
#
#
# ----------
# ❓Pred Property name: Net Worth in 2007
# 🙋Predicted value: $1.3 million (equivalent to $1.8 million in 2022)
# ⭐️ Relevant property -->  {'NLP ID (old)': ['a0000002122644']}
#
#
# ----------
# ❓Pred Property name: House Purchase in 2005
# 🙋Predicted value: $1.6 million house in Kenwood, Chicago (equivalent to $2.4 million in 2022)
# ⭐️ Relevant property -->  {'father': ['Barack Obama Sr.']}
#
#
# ----------
# ❓Pred Property name: Income in 2009
# 🙋Predicted value: $5.5 million
# ⭐️ Relevant property -->  {'employer': ['Business International Corporation', 'New York Public Interest Research Group', 'Gamaliel Foundation', 'Sidley Austin', 'University of Chicago']}
#
#
# ----------
# ❓Pred Property name: Charitable Donation in 2010
# 🙋Predicted value: $131,000 to Fisher House Foundation
# ⭐️ Relevant property -->  {'award received': ['Nobel Peace Prize', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'Presidential Medal of Distinction', 'Time Person of the Year', 'Time Person of the Year', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction', "NAACP Image Award – Chairman's Award", 'German Media Award', 'King Abdulaziz Medal', 'Order of Sikatuna', 'National Medal of Science', 'honorary doctorate from the University of Notre Dame', 'honorary doctor of the Northwestern University', 'honorary doctor of the University of Johannesburg', 'Order of the Rajamitrabhorn', 'Knight Commander of the Order of the British Empire', 'Romy', 'Primetime Emmy Award for Outstanding Narrator', 'Financial Times Person of the Year', 'Phoenix Award', 'Audie Award for Narration by the Author', 'Profile in Courage Award']}
#
#
# ----------
# ❓Pred Property name: Religious Views
# 🙋Predicted value: Protestant Christian, described his religious beliefs and journey in The Audacity of Hope
# ⭐️ Relevant property -->  {'Reddit username': ['PresidentObama']}
#
#
# ----------
# ❓Pred Property name: Church Affiliations
# 🙋Predicted value: ['Trinity United Church of Christ (1992-2008)', 'Shiloh Baptist Church', "St. John's Episcopal Church", 'Evergreen Chapel at Camp David']
# ⭐️ Relevant property -->  {'archives at': ['Stuart A. Rose Manuscript, Archives, and Rare Book Library']}
#
#
# ----------
# ❓Pred Property name: Law Firm
# 🙋Predicted value: Davis, Miner, Barnhill & Galland (1993-2004)
# ⭐️ Relevant property -->  {'employer': ['Business International Corporation', 'New York Public Interest Research Group', 'Gamaliel Foundation', 'Sidley Austin', 'University of Chicago']}
#
#
# ----------
# ❓Pred Property name: Board Memberships
# 🙋Predicted value: ['Woods Fund of Chicago (1994-2002)', 'Joyce Foundation (1994-2002)', 'Chicago Annenberg Challenge (1995-2002)']
# ⭐️ Relevant property -->  {'member of': ['American Academy of Arts and Sciences', 'American Philosophical Society', '109th United States Congress', '110th United States Congress', 'Congressional Black Caucus']}
#
#
# ----------
# ❓Pred Property name: Illinois Senate Period
# 🙋Predicted value: 1996-2004
# ⭐️ Relevant property -->  {'LittleSis people ID': ['13503']}
#
#
# ----------
# ❓Pred Property name: Legislation Sponsored
# 🙋Predicted value: ['Ethics and health care laws reform', 'Increased tax credits for low-income workers', 'Welfare reform and increased subsidies for childcare', 'Legislation to monitor racial profiling and mandate videotaping of homicide interrogations', 'Death penalty reforms, Iran Sanctions Enabling Act, and others']
# ⭐️ Relevant property -->  {'nominated for': ['Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction']}
#
#
# ----------
# ❓Pred Property name: U.S. Senate Period
# 🙋Predicted value: 2005-2008
# ⭐️ Relevant property -->  {'United States House of Representatives ID': ['19276']}
#
#
# ----------
# ❓Pred Property name: Initiatives Introduced
# 🙋Predicted value: ['Lugar–Obama (Nunn–Lugar Cooperative Threat Reduction concept)', 'Federal Funding Accountability and Transparency Act of 2006', 'Strengthening Transparency and Accountability in Federal Spending Act of 2008']
# ⭐️ Relevant property -->  {'Our Campaigns candidate ID': ['4577']}
#
#
# ----------
# ❓Pred Property name: Legislation Sponsored in Senate
# 🙋Predicted value: ['Democratic Republic of the Congo Relief, Security, and Democracy Promotion Act', 'Corporate jet provision to Honest Leadership and Open Government Act', 'Amendment to Defense Authorization Act for safeguarding personality-disorder military discharges', "State Children's Health Insurance Program amendment", 'Various foreign relations and homeland security related legislation']
# ⭐️ Relevant property -->  {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']}
#
#
# ----------
# ❓Pred Property name: Presidential Campaigns
# 🙋Predicted value: ['2008: Won the presidency with 365 electoral votes, first African-American to be elected president', '2012: Reelected as president']
# ⭐️ Relevant property -->  {'Our Campaigns candidate ID': ['4577']}
#
#
# ----------
# ❓Pred Property name: Electoral Votes in 2012
# 🙋Predicted value: 332
# ⭐️ Relevant property -->  {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']}
#
#
# ----------
# ❓Pred Property name: Popular Vote Percentage in 2012
# 🙋Predicted value: 51.1%
# ⭐️ Relevant property -->  {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']}
#
#
# ----------
# ❓Pred Property name: First Democratic President since FDR to Win Majority of Popular Vote Twice
# 🙋Predicted value: True
# ⭐️ Relevant property -->  {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']}
#
#
# ----------
# ❓Pred Property name: Reelection Address Location
# 🙋Predicted value: Chicago's McCormick Place
# ⭐️ Relevant property -->  {'candidacy in election': ['2004 United States Senate election in Illinois', '2008 United States presidential election', '2012 United States presidential election', '2008 Arkansas Democratic primary', '2012 United States presidential election in Washington (state)', '2012 United States presidential election in Missouri', '2012 United States presidential election in Oklahoma', '2012 United States presidential election in New Jersey']}
#
#
# ----------
# ❓Pred Property name: Free Trade Pact Advocated
# 🙋Predicted value: Trans-Pacific Partnership
# ⭐️ Relevant property -->  {'political ideology': ['feminism', 'gun control']}
#
#
# ----------
# ❓Pred Property name: Environmental Policy Actions
# 🙋Predicted value: ['Established a federal investigation after the Macondo Prospect oil leak', 'Announced a six-month moratorium on new deepwater drilling permits and leases', 'Permanently banned new offshore oil and gas drilling in most U.S.-owned waters in the Atlantic and Arctic Oceans', 'Created 25 new national monuments and expanded four others under the Antiquities Act']
# ⭐️ Relevant property -->  {'political ideology': ['feminism', 'gun control']}
#
#
# ----------
# ❓Pred Property name: Environmental Policy Land Protection
# 🙋Predicted value: Protected a total of 553,000,000 acres of federal lands and waters
# ⭐️ Relevant property -->  {'political ideology': ['feminism', 'gun control']}
#
#
# ----------
# ❓Pred Property name: United Nations Resolution on Israeli Settlements (2011)
# 🙋Predicted value: Vetoed a Security Council resolution condemning Israeli settlements in 2011, with the United States being the only nation to do so
# ⭐️ Relevant property -->  {'National Library of Israel J9U ID': ['987007304957705171']}
#
#
# ----------
# ❓Pred Property name: Support for Two-State Solution
# 🙋Predicted value: Supports the two-state solution to the Arab–Israeli conflict based on the 1967 borders with land swaps
# ⭐️ Relevant property -->  {'described at URL': ["http://www.treccani.it/enciclopedia/barack-obama_(Il-Libro-dell'Anno)/", 'https://www.whitehouse.gov/about-the-white-house/presidents/barack-obama/']}
#
#
# ----------
# ❓Pred Property name: Comparison of Zionist Movement to Civil Rights Movement
# 🙋Predicted value: Likened the Zionist movement to the civil rights movement in the United States in 2014, stating that both seek to bring justice and equal rights to historically persecuted peoples
# ⭐️ Relevant property -->  {'political ideology': ['feminism', 'gun control']}
#
#
# ----------
# ❓Pred Property name: Support for Israel's Right to Defend Itself
# 🙋Predicted value: Expressed support for Israel's right to defend itself during the 2014 Israel–Gaza conflict
# ⭐️ Relevant property -->  {'National Library of Israel J9U ID': ['987007304957705171']}
#
#
# ----------
# ❓Pred Property name: United Nations Resolution 2334 Abstention
# 🙋Predicted value: Under the Obama Administration, the United States abstained from United Nations Security Council Resolution 2334 in 2016, allowing it to pass and condemning Israeli settlement building in the occupied Palestinian territories
# ⭐️ Relevant property -->  {'IdRef ID': ['118177257']}
#
#
# ----------
# ❓Pred Property name: Presidential Library
# 🙋Predicted value: The Barack Obama Presidential Center will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.
# ⭐️ Relevant property -->  {'National Library of Israel J9U ID': ['987007304957705171']}
#
#
# ----------
# ❓Pred Property name: Awards and Honors
# 🙋Predicted value: ['Nobel Peace Prize in 2009', 'Ambassador of Humanity Award in 2014', 'Profile in Courage Award in 2017', 'Ripple of Hope Award in 2018', 'Time Person of the Year in 2008 and 2012', 'Two Grammy Awards for Best Spoken Word Album', 'Two Primetime Emmy Awards for Outstanding Narrator', "Two Children's and Family Emmy Awards"]
# ⭐️ Relevant property -->  {'award received': ['Nobel Peace Prize', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'Presidential Medal of Distinction', 'Time Person of the Year', 'Time Person of the Year', 'Grammy Award for Best Audio Book, Narration & Storytelling Recording', 'NAACP Image Award for Outstanding Literary Work, Nonfiction', "NAACP Image Award – Chairman's Award", 'German Media Award', 'King Abdulaziz Medal', 'Order of Sikatuna', 'National Medal of Science', 'honorary doctorate from the University of Notre Dame', 'honorary doctor of the Northwestern University', 'honorary doctor of the University of Johannesburg', 'Order of the Rajamitrabhorn', 'Knight Commander of the Order of the British Empire', 'Romy', 'Primetime Emmy Award for Outstanding Narrator', 'Financial Times Person of the Year', 'Phoenix Award', 'Audie Award for Narration by the Author', 'Profile in Courage Award']}
#
#
# ----------
# ❓Pred Property name: Bought Stocks in
# 🙋Predicted value: ['Tesla', 'Nvidia', 'Hertz']
# ⭐️ Relevant property -->  {'participant in': ['commencement at the Knox College', 'commencement at the University of Notre Dame', 'World Government Summit 2016']}
#
#
# ----------
# ❓Pred Property name: Favourite Fast Food Chain
# 🙋Predicted value: McDonalds
# ⭐️ Relevant property -->  {'InfluenceWatch influencer': ['person/barack-obama']}

# %% [markdown]
# # Evaluate!

# %%
'''
KG -> a wikidata Entity
case: find the actual wikidata entity then eval. If you can't find a page -> print error
search wikidata for string

'''

# %%
idx = 0
results = []
assert pred_kbs[idx]['entity_label'] == ref_kbs[idx]['entity_label']

pred_kbs[idx]['reference_knowledge_graph'] = ref_kbs[idx]

# Add some (presumably) wrong properties
pred_kbs[idx]['properties']['Bought Stocks in'] = ['Tesla', 'Nvidia', 'Hertz']
pred_kbs[idx]['properties']['Favourite Fast Food Chain'] = 'McDonalds'

results.append(ReferenceKGValidator(**pred_kbs[idx]))

# %%
results[0].model_dump()['validated_properties']
# Out:
# [{'property_name': 'Birth Place',
#   'property_value': 'Honolulu, Hawaii',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted birth place 'Honolulu, Hawaii' does not match any of the known birth places for Barack Obama, which are 'Kapiolani Medical Center for Women and Children' and 'Honolulu'."},
#  {'property_name': 'Birthday',
#   'property_value': 'August 4, 1961',
#   'property_is_valid': True,
#   'is_valid_reason': "The predicted property 'Birthday' matches the reference property 'date of birth' which is '+1961-08-04T00:00:00Z' for Barack Obama.",
#   'error_message': None},
#  {'property_name': 'Party',
#   'property_value': 'Democratic Party',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama is a member of the Democratic Party.',
#   'error_message': None},
#  {'property_name': 'Education',
#   'property_value': ['Columbia University',
#    'Harvard Law School',
#    'Occidental College'],
#   'property_is_valid': True,
#   'is_valid_reason': 'The predicted property value includes educational institutions where Barack Obama is known to have attended such as Columbia University, Harvard Law School, and Occidental College.',
#   'error_message': None},
#  {'property_name': 'Net Worth in 2007',
#   'property_value': '$1.3 million (equivalent to $1.8 million in 2022)',
#   'property_is_valid': True,
#   'is_valid_reason': 'Net worth information for public figures like Barack Obama is commonly reported and available. The conversion to 2022 provides relevant context for comparison.',
#   'error_message': None},
#  {'property_name': 'House Purchase in 2005',
#   'property_value': '$1.6 million house in Kenwood, Chicago (equivalent to $2.4 million in 2022)',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'House Purchase in 2005' is not a valid property for the entity 'Barack Obama'. Please provide a valid property name for validation."},
#  {'property_name': 'Income in 2009',
#   'property_value': '$5.5 million',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "There is no reference property specifically related to 'Income' for the entity 'Barack Obama'. Please provide a valid predicted property based on the reference properties available: {'employer': ['Business International Corporation', 'New York Public Interest Research Group', 'Gamaliel Foundation', 'Sidley Austin', 'University of Chicago']}"},
#  {'property_name': 'Charitable Donation in 2010',
#   'property_value': '$131,000 to Fisher House Foundation',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': 'Predicted property is not a valid property for the entity'},
#  {'property_name': 'Religious Views',
#   'property_value': 'Protestant Christian, described his religious beliefs and journey in The Audacity of Hope',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': 'Religious Views for Barack Obama is not a valid predicted property based on the reference properties available.'},
#  {'property_name': 'Church Affiliations',
#   'property_value': ['Trinity United Church of Christ (1992-2008)',
#    'Shiloh Baptist Church',
#    "St. John's Episcopal Church",
#    'Evergreen Chapel at Camp David'],
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'Church Affiliations' is not a standard or commonly documented property for the entity 'Barack Obama'. Please provide a valid candidate property for validation."},
#  {'property_name': 'Law Firm',
#   'property_value': 'Davis, Miner, Barnhill & Galland (1993-2004)',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "Predicted property 'Law Firm' is not a valid property for the entity 'Barack Obama'."},
#  {'property_name': 'Board Memberships',
#   'property_value': ['Woods Fund of Chicago (1994-2002)',
#    'Joyce Foundation (1994-2002)',
#    'Chicago Annenberg Challenge (1995-2002)'],
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'Board Memberships' is not a valid property for the entity 'Barack Obama'. Please provide a valid property for the entity."},
#  {'property_name': 'Illinois Senate Period',
#   'property_value': '1996-2004',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'Illinois Senate Period' is not valid for the entity 'Barack Obama'. Barack Obama was a United States Senator from Illinois, not a member of the Illinois Senate during the years 1996-2004."},
#  {'property_name': 'Legislation Sponsored',
#   'property_value': ['Ethics and health care laws reform',
#    'Increased tax credits for low-income workers',
#    'Welfare reform and increased subsidies for childcare',
#    'Legislation to monitor racial profiling and mandate videotaping of homicide interrogations',
#    'Death penalty reforms, Iran Sanctions Enabling Act, and others'],
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama, as a former President of the United States, sponsored several legislations including those mentioned.',
#   'error_message': None},
#  {'property_name': 'U.S. Senate Period',
#   'property_value': '2005-2008',
#   'property_is_valid': False,
#   'is_valid_reason': 'Barack Obama served as a U.S. Senator from 2005 to 2008.',
#   'error_message': 'Barack Obama was a member of the United States Senate, not the House of Representatives.'},
#  {'property_name': 'Initiatives Introduced',
#   'property_value': ['Lugar–Obama (Nunn–Lugar Cooperative Threat Reduction concept)',
#    'Federal Funding Accountability and Transparency Act of 2006',
#    'Strengthening Transparency and Accountability in Federal Spending Act of 2008'],
#   'property_is_valid': True,
#   'is_valid_reason': "The initiatives introduced are valid and relevant to Barack Obama's political career.",
#   'error_message': None},
#  {'property_name': 'Legislation Sponsored in Senate',
#   'property_value': ['Democratic Republic of the Congo Relief, Security, and Democracy Promotion Act',
#    'Corporate jet provision to Honest Leadership and Open Government Act',
#    'Amendment to Defense Authorization Act for safeguarding personality-disorder military discharges',
#    "State Children's Health Insurance Program amendment",
#    'Various foreign relations and homeland security related legislation'],
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "Predicted property 'Legislation Sponsored in Senate' is not a valid property for the entity 'Barack Obama'. Please provide a valid predicted property for the entity."},
#  {'property_name': 'Presidential Campaigns',
#   'property_value': ['2008: Won the presidency with 365 electoral votes, first African-American to be elected president',
#    '2012: Reelected as president'],
#   'property_is_valid': True,
#   'is_valid_reason': 'The predicted property aligns with the reference properties for Barack Obama',
#   'error_message': None},
#  {'property_name': 'Electoral Votes in 2012',
#   'property_value': 332,
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama won 332 electoral votes in the 2012 United States presidential election.',
#   'error_message': None},
#  {'property_name': 'Popular Vote Percentage in 2012',
#   'property_value': '51.1%',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "Predicted property is not valid. The property 'Popular Vote Percentage in 2012' is not a known property for the entity 'Barack Obama'. Valid properties for Barack Obama include 'candidacy in election' such as '2004 United States Senate election in Illinois', '2008 United States presidential election', and '2012 United States presidential election'."},
#  {'property_name': 'First Democratic President since FDR to Win Majority of Popular Vote Twice',
#   'property_value': True,
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': 'Barack Obama is not the first Democratic President since FDR to win the majority of popular vote twice. This property is not valid for Barack Obama based on historical information.'},
#  {'property_name': 'Reelection Address Location',
#   'property_value': "Chicago's McCormick Place",
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'Reelection Address Location' is not valid for the entity 'Barack Obama'. The property does not align with the reference properties related to candidacy in elections for Barack Obama."},
#  {'property_name': 'Free Trade Pact Advocated',
#   'property_value': 'Trans-Pacific Partnership',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "There is no direct connection between the candidate property 'Free Trade Pact Advocated' and the entity 'Barack Obama' based on the reference properties provided."},
#  {'property_name': 'Environmental Policy Actions',
#   'property_value': ['Established a federal investigation after the Macondo Prospect oil leak',
#    'Announced a six-month moratorium on new deepwater drilling permits and leases',
#    'Permanently banned new offshore oil and gas drilling in most U.S.-owned waters in the Atlantic and Arctic Oceans',
#    'Created 25 new national monuments and expanded four others under the Antiquities Act'],
#   'property_is_valid': True,
#   'is_valid_reason': 'The environmental policy actions listed align with actions taken by Barack Obama during his presidency.',
#   'error_message': None},
#  {'property_name': 'Environmental Policy Land Protection',
#   'property_value': 'Protected a total of 553,000,000 acres of federal lands and waters',
#   'property_is_valid': True,
#   'is_valid_reason': None,
#   'error_message': None},
#  {'property_name': 'United Nations Resolution on Israeli Settlements (2011)',
#   'property_value': 'Vetoed a Security Council resolution condemning Israeli settlements in 2011, with the United States being the only nation to do so',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'United Nations Resolution on Israeli Settlements (2011)' for the entity 'Barack Obama' is not a known property in the reference knowledge graph."},
#  {'property_name': 'Support for Two-State Solution',
#   'property_value': 'Supports the two-state solution to the Arab–Israeli conflict based on the 1967 borders with land swaps',
#   'property_is_valid': True,
#   'is_valid_reason': 'Barack Obama has expressed support for a two-state solution to the Arab–Israeli conflict based on the 1967 borders with land swaps.',
#   'error_message': None},
#  {'property_name': 'Comparison of Zionist Movement to Civil Rights Movement',
#   'property_value': 'Likened the Zionist movement to the civil rights movement in the United States in 2014, stating that both seek to bring justice and equal rights to historically persecuted peoples',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "This predicted property is not valid for the entity 'Barack Obama' based on the reference properties available. The candidate property does not align with any known political ideology of 'Barack Obama' such as feminism or gun control."},
#  {'property_name': "Support for Israel's Right to Defend Itself",
#   'property_value': "Expressed support for Israel's right to defend itself during the 2014 Israel–Gaza conflict",
#   'property_is_valid': True,
#   'is_valid_reason': "Barack Obama did express support for Israel's right to defend itself during the 2014 Israel-Gaza conflict.",
#   'error_message': None},
#  {'property_name': 'United Nations Resolution 2334 Abstention',
#   'property_value': 'Under the Obama Administration, the United States abstained from United Nations Security Council Resolution 2334 in 2016, allowing it to pass and condemning Israeli settlement building in the occupied Palestinian territories',
#   'property_is_valid': True,
#   'is_valid_reason': 'The property accurately describes the stance of the Obama Administration on United Nations Resolution 2334 in 2016, where the United States indeed abstained from the resolution.',
#   'error_message': None},
#  {'property_name': 'Presidential Library',
#   'property_value': 'The Barack Obama Presidential Center will be hosted by the University of Chicago and located in Jackson Park on the South Side of Chicago.',
#   'property_is_valid': True,
#   'is_valid_reason': 'The Barack Obama Presidential Center is a real entity planned to be located at the University of Chicago in Jackson Park, Chicago. It serves as a presidential library and museum for Barack Obama.',
#   'error_message': None},
#  {'property_name': 'Awards and Honors',
#   'property_value': ['Nobel Peace Prize in 2009',
#    'Ambassador of Humanity Award in 2014',
#    'Profile in Courage Award in 2017',
#    'Ripple of Hope Award in 2018',
#    'Time Person of the Year in 2008 and 2012',
#    'Two Grammy Awards for Best Spoken Word Album',
#    'Two Primetime Emmy Awards for Outstanding Narrator',
#    "Two Children's and Family Emmy Awards"],
#   'property_is_valid': True,
#   'is_valid_reason': "The predicted awards and honors align with the reference properties of 'award received' for Barack Obama.",
#   'error_message': None},
#  {'property_name': 'Bought Stocks in',
#   'property_value': ['Tesla', 'Nvidia', 'Hertz'],
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "The predicted property 'Bought Stocks in' is not a valid property for the entity 'Barack Obama'. Consider reevaluating the predicted property based on the reference properties and the knowledge of the world."},
#  {'property_name': 'Favourite Fast Food Chain',
#   'property_value': 'McDonalds',
#   'property_is_valid': False,
#   'is_valid_reason': None,
#   'error_message': "Predicted property 'Favourite Fast Food Chain' is not a valid property for entity 'Barack Obama'."}]

# %%
results_json = [r.model_dump() for r in results]
save_jsonl(results_json, '../../data/ref_kg_context_evaluation_results.jsonl')
# Out:
# Saved to f'../../data/text_context_evaluation_results.jsonl

# %% [markdown]
# # Look at our Evaluations

# %%
results = read_jsonl('../../data/ref_kg_context_evaluation_results.jsonl')
len(results)
# Out:
# 1
